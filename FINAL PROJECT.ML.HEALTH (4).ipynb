# %% [markdown]
# # HOSPITAL_READMISSIONS

# %%
import pandas as pd

# %% [markdown]
# Hospital_Readmissions dataset contains 25000 rows and 17 columns.It's aim is to build a machine learning model that predicts whether a patient will be readmitted to the hospital and when.That means the project focuses on analyzing hospital readmission data to understand patterns and factors contributing to patients being readmitted after discharge.

# %%
a=pd.read_csv('hospital_readmissions.csv')
a
# Out:
#            age  time_in_hospital  n_lab_procedures  n_procedures  \
# 0      [70-80)                 8                72             1
# 1      [70-80)                 3                34             2
# 2      [50-60)                 5                45             0
# 3      [70-80)                 2                36             0
# 4      [60-70)                 1                42             0
# ...        ...               ...               ...           ...
# 24995  [80-90)                14                77             1
# 24996  [80-90)                 2                66             0
# 24997  [70-80)                 5                12             0
# 24998  [70-80)                 2                61             3
# 24999  [50-60)                10                37             1
#
#        n_medications  n_outpatient  n_inpatient  n_emergency  \
# 0                 18             2            0            0
# ...

# %%
a.shape
# Out:
# (25000, 17)

# %%
a.head()
# Out:
#        age  time_in_hospital  n_lab_procedures  n_procedures  n_medications  \
# 0  [70-80)                 8                72             1             18
# 1  [70-80)                 3                34             2             13
# 2  [50-60)                 5                45             0             18
# 3  [70-80)                 2                36             0             12
# 4  [60-70)                 1                42             0              7
#
#    n_outpatient  n_inpatient  n_emergency medical_specialty       diag_1  \
# 0             2            0            0           Missing  Circulatory
# 1             0            0            0             Other        Other
# 2             0            0            0           Missing  Circulatory
# 3             1            0            0           Missing  Circulatory
# 4             0            0            0  InternalMedicine        Other
#
# ...

# %%
a.tail()
# Out:
#            age  time_in_hospital  n_lab_procedures  n_procedures  \
# 24995  [80-90)                14                77             1
# 24996  [80-90)                 2                66             0
# 24997  [70-80)                 5                12             0
# 24998  [70-80)                 2                61             3
# 24999  [50-60)                10                37             1
#
#        n_medications  n_outpatient  n_inpatient  n_emergency  \
# 24995             30             0            0            0
# 24996             24             0            0            0
# 24997              6             0            1            0
# 24998             15             0            0            0
# 24999             24             0            0            0
#
#             medical_specialty       diag_1    diag_2       diag_3  \
# 24995                 Missing  Circulatory     Other  Circulatory
# 24996                 Missing    Digestive    Injury        Other
# ...

# %%
a.isnull().sum()
# Out:
# age                  0
# time_in_hospital     0
# n_lab_procedures     0
# n_procedures         0
# n_medications        0
# n_outpatient         0
# n_inpatient          0
# n_emergency          0
# medical_specialty    0
# diag_1               0
# diag_2               0
# diag_3               0
# glucose_test         0
# A1Ctest              0
# change               0
# diabetes_med         0
# readmitted           0
# dtype: int64

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                25000 non-null  object
#  1   time_in_hospital   25000 non-null  int64
#  2   n_lab_procedures   25000 non-null  int64
#  3   n_procedures       25000 non-null  int64
#  4   n_medications      25000 non-null  int64
#  5   n_outpatient       25000 non-null  int64
#  6   n_inpatient        25000 non-null  int64
#  7   n_emergency        25000 non-null  int64
#  8   medical_specialty  25000 non-null  object
#  9   diag_1             25000 non-null  object
#  10  diag_2             25000 non-null  object
#  11  diag_3             25000 non-null  object
#  12  glucose_test       25000 non-null  object
#  13  A1Ctest            25000 non-null  object
#  14  change             25000 non-null  object
#  15  diabetes_med       25000 non-null  object
# ...

# %% [markdown]
# # LABEL ENCODING

# %%
from sklearn.preprocessing import LabelEncoder

# %%
j=LabelEncoder()
k=j.fit_transform(a['age'])
l=j.fit_transform(a['medical_specialty'])
m=j.fit_transform(a['diag_1'])
n=j.fit_transform(a['diag_2'])
o=j.fit_transform(a['diag_3'])
p=j.fit_transform(a['glucose_test'])
q=j.fit_transform(a['A1Ctest'])
r=j.fit_transform(a['change'])
s=j.fit_transform(a['diabetes_med'])
t=j.fit_transform(a['readmitted'])
a['age']=k
a['medical_specialty']=l
a['diag_1']=m
a['diag_2']=n
a['diag_3']=o
a['glucose_test']=p
a['A1Ctest']=q
a['change']=r
a['diabetes_med']=s
a['readmitted']=t
a
# Out:
#        age  time_in_hospital  n_lab_procedures  n_procedures  n_medications  \
# 0        3                 8                72             1             18
# 1        3                 3                34             2             13
# 2        1                 5                45             0             18
# 3        3                 2                36             0             12
# 4        2                 1                42             0              7
# ...    ...               ...               ...           ...            ...
# 24995    4                14                77             1             30
# 24996    4                 2                66             0             24
# 24997    3                 5                12             0              6
# 24998    3                 2                61             3             15
# 24999    1                10                37             1             24
#
# ...

# %% [markdown]
# # CORRELATION

# %%
a.corr()
# Out:
#                         age  time_in_hospital  n_lab_procedures  n_procedures  \
# age                1.000000          0.086268          0.028796     -0.093356
# time_in_hospital   0.086268          1.000000          0.328326      0.179249
# n_lab_procedures   0.028796          0.328326          1.000000      0.048827
# n_procedures      -0.093356          0.179249          0.048827      1.000000
# n_medications     -0.039604          0.449415          0.271741      0.368681
# n_outpatient       0.019860         -0.011309         -0.004309     -0.034796
# n_inpatient       -0.021917          0.076916          0.043713     -0.069078
# n_emergency       -0.070886         -0.013115         -0.004929     -0.042906
# medical_specialty -0.027602          0.043180         -0.073420     -0.017974
# diag_1            -0.017524          0.030004         -0.026125     -0.241709
# diag_2            -0.011906          0.088306          0.052641     -0.121367
# ...

# %%
data=a.drop('n_procedures',axis='columns')
data
# Out:
#        age  time_in_hospital  n_lab_procedures  n_medications  n_outpatient  \
# 0        3                 8                72             18             2
# 1        3                 3                34             13             0
# 2        1                 5                45             18             0
# 3        3                 2                36             12             1
# 4        2                 1                42              7             0
# ...    ...               ...               ...            ...           ...
# 24995    4                14                77             30             0
# 24996    4                 2                66             24             0
# 24997    3                 5                12              6             0
# 24998    3                 2                61             15             0
# 24999    1                10                37             24             0
#
# ...

# %% [markdown]
# # TRAIN_TEST_SPLIT

# %%
from sklearn.model_selection import train_test_split

# %%
x=data.drop('readmitted',axis='columns')
x
# Out:
#        age  time_in_hospital  n_lab_procedures  n_medications  n_outpatient  \
# 0        3                 8                72             18             2
# 1        3                 3                34             13             0
# 2        1                 5                45             18             0
# 3        3                 2                36             12             1
# 4        2                 1                42              7             0
# ...    ...               ...               ...            ...           ...
# 24995    4                14                77             30             0
# 24996    4                 2                66             24             0
# 24997    3                 5                12              6             0
# 24998    3                 2                61             15             0
# 24999    1                10                37             24             0
#
# ...

# %%
y=data.readmitted
y
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 24995    1
# 24996    1
# 24997    1
# 24998    0
# 24999    1
# Name: readmitted, Length: 25000, dtype: int32

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=40)
xtrain,xtest,ytrain,ytest
# Out:
# (       age  time_in_hospital  n_lab_procedures  n_medications  n_outpatient  \
#  2691     3                 6                28             16             0
#  22020    3                 4                45              8             0
#  12983    3                 2                58             18             0
#  21202    1                 3                 9              7             0
#  8748     3                 4                40             10             3
#  ...    ...               ...               ...            ...           ...
#  21810    1                 3                44             10             0
#  23992    3                 1                57              2             0
#  14501    2                 2                51             23             0
#  14555    4                13                55             17             0
#  11590    2                 2                61              9             0
#
# ...

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings('ignore')

# %%
model1=LogisticRegression()
model1.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
model1.predict(xtest)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
model1.score(xtest,ytest)
# Out:
# 0.6092

# %% [markdown]
# # CONFUSION MATRIX OF LOGISTIC REGRESSION

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.metrics import confusion_matrix

# %%
y_pred=model1.predict(xtest)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
cm=confusion_matrix(y_pred,ytest)
cm
# Out:
# array([[2101, 1383],
#        [ 571,  945]], dtype=int64)

# %%
import seaborn as sn

# %%
sn.heatmap(cm,annot=True)
plt.xlabel('predicted')
plt.ylabel('truth')
plt.figure(figsize=(20,7))

# %% [markdown]
# This confusion matrix shows the performance of linear model.It correctly classified 2101 true negatives, 1383 false positives, 571 false negatives and 945 true positives.

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC

# %%
model2=SVC()
model2.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
model2.predict(xtest)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
model2.score(xtest,ytest)
# Out:
# 0.5922

# %% [markdown]
# # KERNELS (LINEAR, POLY, RBF)

# %% [markdown]
# # LINEAR

# %%
model3=SVC(kernel='linear')
model3.fit(xtrain,ytrain)
# Out:
# SVC(kernel='linear')

# %%
model3.predict(xtest)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
model3.score(xtest,ytest)
# Out:
# 0.5944

# %% [markdown]
# # POLY

# %%
model4=SVC(kernel='poly')
model4.fit(xtrain,ytrain)
# Out:
# SVC(kernel='poly')

# %%
model4.predict(xtest)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
model4.score(xtest,ytest)
# Out:
# 0.5786

# %% [markdown]
# # RBF

# %%
model5=SVC(kernel='rbf')
model5.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
model5.predict(xtest)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
model5.score(xtest,ytest)
# Out:
# 0.5922

# %% [markdown]
# # DECISION TREE CLASSIFIER

# %%
from sklearn import tree

# %%
model6=tree.DecisionTreeClassifier()
model6.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
model6.predict(xtest)
# Out:
# array([1, 1, 1, ..., 0, 1, 0])

# %%
model6.score(xtest,ytest)
# Out:
# 0.5456

# %% [markdown]
# # RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model7=RandomForestClassifier(n_estimators=60)
model7.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(n_estimators=60)

# %%
model7.predict(xtest)
# Out:
# array([0, 0, 1, ..., 0, 1, 1])

# %%
model7.score(xtest,ytest)
# Out:
# 0.5878

# %% [markdown]
# # KNEIGHBORS CLASSIFIER

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model8=KNeighborsClassifier(n_neighbors=4)
model8.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
model8.predict(xtest)
# Out:
# array([0, 1, 0, ..., 0, 1, 0])

# %%
model8.score(xtest,ytest)
# Out:
# 0.5468

# %% [markdown]
# # NAIVE BAYES

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model9=GaussianNB()
model9.fit(xtrain,ytrain)
# Out:
# GaussianNB()

# %%
model9.predict(xtest)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
model9.score(xtest,ytest)
# Out:
# 0.5858

# %% [markdown]
# # XGB CLASSIFIER

# %%
from xgboost import XGBClassifier

# %%
model10=XGBClassifier()
model10.fit(xtrain,ytrain)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
model10.predict(xtest)
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
model10.score(xtest,ytest)
# Out:
# 0.5912

# %% [markdown]
# # VISUALIZATION

# %%
import seaborn as sns

# %%
sns.countplot(x='readmitted', data=data)
plt.title('Readmitted Class Distribution')
plt.xlabel('Readmitted (0=No, 1=Yes)')
plt.ylabel('count')
plt.show()

# %% [markdown]
# The bar chart shows that most patients were not readmitted (class 0), while a slightly smaller number were readmitted (class 1).The class distribution is nearly balanced.

# %%
numeric_features = ['time_in_hospital', 'n_lab_procedures', 'n_medications', 'n_outpatient', 'n_inpatient', 'n_emergency']
data[numeric_features].hist(figsize=(10,8), bins=15)
plt.suptitle('Distribution of Numeric Features')
plt.show()

# %% [markdown]
# Most patients stayed in the hospital for a few days and had some lab tests and medicines.Very few patients had visited the hospital before, either as outpatients, inpatients, or in emergencies.Most of those values are close to zero.
